# %% [markdown]
# ## Домашнее задание 6
# ### Дедлайн - 10 ноября 23:59

# %% [markdown]
# Вам нужно обкачать новости (или статьи) с сайтов газет или аналогичных онлайн-изданий и записать это в датафрейм, затем сохранить как csv. Новости или статьи обязательно должны быть с тематическими тегами ()! Через пару месяцев мы на основе этих данных будем делать классификацию текстов.
#
# **Данные**
# Можно выбрать один из этих источников или взять свой. Обязательно напишите, какой источник вы берете, чтобы данные не пересекались
#
# - https://ircity.ru/text/ Новости Иркутска
# - http://74vpered.ru/novosti/?start=0 Газета города Троицка Челябинской области
# - https://progorod43.ru/news Новости Вятки
# - https://nash-kislovodsk.ru/news Новости Кисловодска
# - https://kaluga24.tv/home/news Новости Калуги
# - https://kostroma.today/news/ Кострома Тудей
#
#
# **Совет по выбору**
#
# Легче всего, если:
#
# - навигация по страницам/выпускам/датам - под/над есть что-то вроде 1, 2, 3, ... 45, 46 по которым переход на страницы (например, Медуза - это плохой вариант, там кнопка "показать еще", сайт Вышки  - хороший вариант: там внизу навигация по страницам)
# - в адресной строке будет навигация вроде <адрес>p=2 или  <адрес>page=2 или что-то такое, например, как на фикбуке ("https://ficbook.net/fanfiction/no_fandom/originals?p=2"). Это можно посмотреть, перейдя на вторую страницу интересующей ленты новостей.
# - региональная газета - там попроще сайт и будет легче доставать информацию (у топовых газет много всего на скриптах и там сложно или невозможно доставать информацию)
#
# Требоавания к ДЗ:
# - Минимальные требования по объему скачивания: 1000 постов/новостей/статей**
# - К каждой статье/новости должны быть тематические теги
# - Данные сохраняются в датафрейм, есть описание данных
# - Код программы разделен на логичные функции и классы (а не все подряд в цикле)
# - Есть обработка ошибок (try-except), куда-то сохраняется информация о том, какие посты не скачались и какая ошибка
# - Посчитаны какие-то базовые статистики:
#    - самые популярные теги (или другой параметр в вашей газете)
#
# **Подсказка** используйте библиотеку tqdm для удобного отслеживания прогресса.
#
# **Вы должны сдать**
#
# - программу-краулер
# - файл csv со статьями и тегами

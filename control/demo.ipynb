# %% [markdown]
# ## Задание 1
#
# Используя библиотеку requests, получите данные из открытого источника. В качестве примера будет использован набор данных из COVID-19 API, содержащий сведения о заболеваемости COVID-19 по странам.

# %%
import requests

url = "https://api.covid19api.com/summary"
### YOUR CODE HERE

# %% [markdown]
# ## Задание 2
#
# Извлеките спаршенную вами информацию из json о всех странах и их текущем состоянии (например, количество новых случаев и смертей) и поместите её в DataFrame с помощью библиотеки pandas.

# %%
import pandas as pd

### YOUR CODE HERE

# %% [markdown]
# Какое общее количество подтвержденных случаев регистрации имеется в данных?

# %% [markdown]
# ## Задание 3
#
# Проведите анализ данных:
#    - Найдите 5 стран с наибольшим количеством новых подтвержденных случаев.
#    - Вопрос: Каковы эти страны и сколько новых случаев регистрации в каждой?

# %% [markdown]
# ## Задание 4
#
# Добавьте в DataFrame новый столбец, рассчитывающий смертность (TotalDeaths / TotalConfirmed) * 100.
#    - Вопрос: У какой страны самый высокий показатель смертности?

# %% [markdown]
# ## Задание 5: Визуализация данных
#
# Используя библиотеки matplotlib и seaborn, создайте график, показывающий 10 стран с наибольшим случаев COVID.
#
# Вопрос: Какие страны выделяются на графике и почему?

# %% [markdown]
# ## Задание 6: Классы и исключения
#
# Создайте класс CountryCovidData, который будет содержать информацию о стране и методы для получения анализа по COVID-19:
#    - Атрибуты: название страны, число подтвержденных случаев, число смертей.
#    - Метод для вычисления уровня смертности.
#    - Исключите возникновение ошибок, если данные о подтвержденных случаях равны нулю, реализовав собственное исключение.
#
# Как ваше исключение обрабатывает случай, когда количество подтвержденных случаев равно нулю?

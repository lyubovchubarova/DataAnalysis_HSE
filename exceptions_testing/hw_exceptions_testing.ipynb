# %% [markdown]
# ## Домашнее задание 7, дедлайн 20 ноября 23:59
#
# ### Задача 1.1 (2 балла)
#
# Ах, как же прекрасно решать квадратные уравнения вида `ax^2 + bx + c = 0`
#
# Напишите функцию find_roots, принимающую три параметра: коэффициенты уравнения `a`, `b`, и `c` и возвращающую его корни в виде кортежа из двух значений. Можно пользоваться формулой дискриминанта или теоремой Виета.
#
# ```
# >>find_roots(1, 2, -3) #решаем квадратное уравнение x^2+2x-3=0
# >>> (-3, 1) #корнями этого уравнения являются -3 и 1
# ```
#
# Так же создайте два собственных исключения NoSolutionsError и InfiniteSolutionsError, которые будут вызваны в случае отсутствия и бесконечного количества решений уравнения соответственно.
#
# Если переданные коэффициенты не являются рациональными числами, вызовите исключение TypeError.
#
# ### Задача 1.2 (2 балла)
#
# Напишите тесты для вашего решения. Протестируйте
# 1. Подачу аргументов неправильного типа в функцию
# 2. вызовы всех кастомных исключений
# 3. Правильные решения уравнений
#
# Что-то еще, что можно протестировать - по желанию
#
# ### Задача 2.1 (3 балла)
#
# Представьте, что вам нужно валидировать пароль на сайте.
#
# Напишите функцию `password_validation`, которая принимает один позиционный параметр — пароль, и следующие именованные параметры:
#
# `min_length` — минимальная длина пароля, по умолчанию 8;
# `possible_chars` — строка символов, которые могут быть в пароле, по умолчанию латинские буквы и цифры;
# `at_least_one` — аргумент, который проверяет, чего в пароле должно быть как минимум 1. Пример: минимум 1 заглавная буква, минимум 1 цифра, минимум 1 знак пунктуации. Подумайте над реализацией.
#
# Если переданный позиционный параметр не является строкой, вызовите исключение `TypeError`.
#
# А так же реализуйте собственные исключения:
#
# `MinLengthError` — вызывается, если пароль меньше заданной длины;
# `PossibleCharError` — вызывается, если в пароле используется недопустимый символ;
# `NeedCharError` — вызывается, если в пароле не найдено ни одного обязательного символа.
# Проверка условий должна происходить в порядке указанном в задании.
#
# Так как, хороший разработчик никогда не хранит пароли в открытом виде, функция, в случае успешного завершения, возвращает хеш пароля. Для этого воспользуйтесь функцией `sha256` из пакета `hashlib` и верните его шестнадцатеричное представление. можно вернуться к лекции про типы данных и почитать про хэширование
#
# ### Задача 2.2 (3 балла)
#
# Напишите тесты для всех обозначенных функций и исключений

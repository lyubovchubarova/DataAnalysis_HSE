# %% [markdown]
# ## ДЗ9: визуализация данных
#
# Дедлайн 20 декабря 23:59

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Загрузите датасет tips.
#
# Какие в нем есть поля? Что они обозначают **(1 балл)**

# %%
tips = sns.load_dataset('tips')
### ВАШ КОД И ОТВЕТ ЗДЕСЬ

# %% [markdown]
# Для каждого из графиков добавьте заголовки и подписи осей, чтобы они были понятными. (+1 балл ко всему заданию)
#
# ### Задание 1: Гистограмма. 1.6 балла
#
# 1. Постройте гистограмму для отображения распределения счетов (total_bill)
#    - Используйте seaborn.histplot для создания гистограммы.
#    - Настройте количество бинов для гистограммы.
#    - Вопрос: Какое распределение наблюдается у сумм счетов?
#
# ### Задание 2: Ящик с усами (Boxplot) 1.6 балла
# 2. Постройте ящик с усами для визуализации распределения счетов в зависимости от дня недели.
#    - Как читаеть полученный вами график?
#    - Используйте seaborn.boxplot.
#    - Вопрос: В какой день недели наблюдается наибольшая медиана счета?
#
# ### Задание 3: Рассеивание (Scatter plot) 1.6 балла
# 3. Постройте диаграмму рассеяния, чтобы изучить взаимосвязь между размерами чаевых (tip) и общими счетами (total_bill).
#    - Используйте seaborn.scatterplot.
#    - Добавьте параметр, обозначающий разные маркеры для времени дня (обед/ужин).
#    - Вопрос: Можно ли сказать, что большие счета обычно сопровождаются большими чаевыми?
#
# ### Задание 4: График плотности (KDE plot) 1.6 балла
# 4. Создайте графики плотности для совокупного счета по полу.
#    - Используйте seaborn.kdeplot.
#    - Вопрос: Как различается распределение счетов среди мужчин и женщин?
#
# ### Задание 5: Парная диаграмма (Pairplot) 1.6 балла
# 5. Постройте пару диаграмм, чтобы изучить все пары числовых переменных в датасете.
#    - Используйте seaborn.pairplot.
#    - Вопрос: Какие закономерности или связи можно выделить между переменными?
#
#
# ### Полезные ссылки:
# - [Документация Matplotlib](https://matplotlib.org)
# - [Документация Seaborn](https://seaborn.pydata.org)
